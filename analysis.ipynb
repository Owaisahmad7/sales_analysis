# %% [markdown]
# Statistics in python
# How to check the Normal or Guassian disribution of data

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
def pdf(x):
    mean = np.mean(x)
    std = np.std(x)
    y_out = 1/(std * np.sqrt(2 * np.pi)) * np.exp( - (x - mean)**2 / (2 * std**2))
    return y_out

# %%
# to generate an array of X
x = np.arange(-2, 2, 0.1)
y = pdf(x)

#plotting the normal curve / bell curve or gaussian distribution


plt.figure(figsize=(5,5))

plt.plot(x, y, color = 'blue', linestyle = 'dashed')

plt.scatter(x, y, marker='o', s=25, color='red')

# %%
## Normal Distribution and its test##
#Visual test by Histogram or q-q norm plot

# %%
df=pd.read_csv('bike_sales.csv')
df.head()

df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 18 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   brand                        1000 non-null   str
#  1   model                        1000 non-null   str
#  2   cc                           1000 non-null   int64
#  3   segment                      1000 non-null   str
#  4   year                         1000 non-null   int64
#  5   speedometer_type             1000 non-null   str
#  6   top_speed_kmh                1000 non-null   int64
#  7   mileage_kmpl                 1000 non-null   float64
#  8   fuel_tank_liters             1000 non-null   float64
#  9   factory_price_inr            1000 non-null   int64
#  10  gst_rate_pct                 1000 non-null   float64
#  11  gst_amount_inr               1000 non-null   int64
#  12  ex_showroom_inr              1000 non-null   int64
# ...

# %%
#find rows which are duplicate
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 995    False
# 996    False
# 997    False
# 998    False
# 999    False
# Length: 1000, dtype: bool

# %%
#finding duplicates of specific column in dataset
print(df.duplicated(subset=["model"]))
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 995     True
# 996     True
# 997     True
# 998     True
# 999     True
# Length: 1000, dtype: bool

# %%
print(df["model"].duplicated().sum())
# Out:
# 928

# %%
print(df["model"].duplicated(keep=False).sum())
# Out:
# 1000

# %%
print(df.isnull())
# Out:
#      brand  model     cc  segment   year  speedometer_type  top_speed_kmh  \
# 0    False  False  False    False  False             False          False
# 1    False  False  False    False  False             False          False
# 2    False  False  False    False  False             False          False
# 3    False  False  False    False  False             False          False
# 4    False  False  False    False  False             False          False
# ..     ...    ...    ...      ...    ...               ...            ...
# 995  False  False  False    False  False             False          False
# 996  False  False  False    False  False             False          False
# 997  False  False  False    False  False             False          False
# 998  False  False  False    False  False             False          False
# 999  False  False  False    False  False             False          False
#
#      mileage_kmpl  fuel_tank_liters  factory_price_inr  gst_rate_pct  \
# ...

# %%
print(df.isnull().sum())
# Out:
# brand                          0
# model                          0
# cc                             0
# segment                        0
# year                           0
# speedometer_type               0
# top_speed_kmh                  0
# mileage_kmpl                   0
# fuel_tank_liters               0
# factory_price_inr              0
# gst_rate_pct                   0
# gst_amount_inr                 0
# ex_showroom_inr                0
# on_road_price_inr              0
# overall_score                  0
# price_increase_scenario_pct    0
# buyer_behaviour                0
# price_sensitivity              0
# dtype: int64
